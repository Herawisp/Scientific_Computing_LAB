# %% [markdown]
# <a href="https://colab.research.google.com/github/Herawisp/Scientific_Computing_LAB/blob/main/SC_Sesi5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CATATAN

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-v0_8-whitegrid')
# %matplotlib inline

h = 0.1
x = np.arange(0, 2 * np.pi, h)
y = np.cos(x)

forward_diff = np.diff(y) / h
x_diff = x[1:]

exact_solution = -np.sin(x_diff)

plt.figure(figsize=(12, 8))
plt.plot(x_diff, forward_diff, '--', \
          label = 'Finite difference approximation')
plt.plot(x_diff, exact_solution, \
          label = 'Exact solution')
plt.legend()
plt.show()

max_error = np.max(np.abs(forward_diff - exact_solution))
print(max_error)
# Out:
# 0.04997039864231646

# %% [markdown]
# ## Rieman Integral

# %%
import numpy as np

def f(x):
    return 4*x**4 + 2*x**3 - 6*x

a = -3
b = 3
n = 30

lebar = (b - a)/(n - 1)
x = np.linspace(a, b, n)
y = f(x)

left_riemann = lebar * sum(y[:n-1])
right_riemann = lebar * sum(y[1:])

print("Left Riemann Sum:", left_riemann)
print("Right Riemann Sum:", right_riemann)
# Out:
# Left Riemann Sum: 384.4323034267851
# Right Riemann Sum: 399.328855150923

# %%
a = -3
b = 3
n = 30

lebar = (b - a)/(n - 1)
x_aid = (x[:n-1] + x[1:]) / 2
y_aid = f(x_aid)

middle_riemann = lebar * sum(y_aid)
print("Middle Riemann Sum:", middle_riemann)
# Out:
# Middle Riemann Sum: 387.26026006636687

# %% [markdown]
# ## Trapezoid Rule

# %%
a = -3
b = 3
n = 30

lebar = (b - a)/(n - 1)
x_aid = (x[:n-1] + x[1:]) / 2
y_aid = f(x_aid)

trapezoid = (lebar * (y[0] + 2 * sum(y[1:n-1]) + y[n-1])) / 2
print("Trapezoid Sum:", trapezoid)
# Out:
# Trapezoid Sum: 391.88057928885405

# %% [markdown]
# ## Simpson's Rule

# %%
#simpson's rule

a =0
b = np.pi
n = 10
h = (b-a) / n
x = np.linspace(a, b, n + 1)
f = np.sin(x)

S = (h / 3) * (y[0] + 4 *sum(y[:n:2]) + 2 * sum(y[1:n:2]) + y[n])
exact = 2

error = abs(5- exact)
print("Error:", error)
print("Simpson's 1/3 Rule:", S)
# Out:
# Error: 3
# Simpson's 1/3 Rule: 364.2110906798806

# %% [markdown]
# # MODUL

# %% [markdown]
# ![WhatsApp Image 2025-05-22 at 18.45.58 (1).jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ## No 1

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-v0_8-whitegrid')
# %matplotlib inline

h = 0.1
x = np.array([0, 0.1, 0.2, 0.3, 0.4])
y = np.array([0, 0.0819, 0.1341, 0.1646, 0.1797])

forward_diff = np.diff(y) / h
x_diff = x[:-1]

exact_solution = -np.sin(x_diff)

plt.figure(figsize=(12, 8))
plt.plot(x_diff, forward_diff, '--', label = 'Finite difference approximation')
plt.plot(x_diff, exact_solution, label = 'Exact solution')
plt.legend()
plt.show()

max_error = np.max(np.abs(forward_diff - exact_solution))
print(max_error)
# Out:
# 0.819

# %% [markdown]
# ## No 2

# %%
import numpy as np

def f(x):
    return np.sin(x)

a = 0
b = np.pi
n = 9

lebar = (b - a)/(n - 1)
x_aid = np.linspace(a, b, n)
y_aid = f(x_aid)

trapezoid_8_panel = (lebar / 2) * (y_aid[0] + 2 * np.sum(y_aid[1:-1]) + y_aid[-1])
print(f"Approximate integral with 8 panels: {trapezoid_8_panel}")

a = 0
b = np.pi
n = 17

lebar = (b - a)/(n - 1)
x_aid = np.linspace(a, b, n)
y_aid = f(x_aid)

trapezoid_8_panel = (lebar / 2) * (y_aid[0] + 2 * np.sum(y_aid[1:-1]) + y_aid[-1])
print(f"Approximate integral with 16 panels: {trapezoid_8_panel}")
# Out:
# Approximate integral with 8 panels: 1.9742316019455508
# Approximate integral with 16 panels: 1.9935703437723395
